# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
cities
# Out:
# ['lavrentiya',
#  'aklavik',
#  'qaanaaq',
#  'saskylakh',
#  'buraydah',
#  'barentsburg',
#  'mahebourg',
#  'busselton',
#  'bredasdorp',
#  'kalmunai',
#  'hilo',
#  'ushuaia',
#  'tasiilaq',
#  'nouadhibou',
#  'chuy',
#  'lompoc',
#  'punta arenas',
#  'albany',
#  'dikson',
#  'atuona',
#  'basco',
#  'malatya',
#  'cape town',
#  'binzhou',
#  'methoni',
#  'vaini',
#  'port elizabeth',
#  'vao',
#  'saint george',
#  'illoqqortoormiut',
#  'abha',
#  'tambilil',
#  'saint-philippe',
#  'grand river south east',
#  'georgetown',
#  'hithadhoo',
#  'dinsor',
#  'kapaa',
#  'taolanaro',
#  'nikolskoye',
#  'beringovskiy',
#  'ixtapa',
#  'san policarpo',
#  'caconde',
#  'bambous virieux',
#  'san cristobal',
#  'new norfolk',
#  'itaituba',
#  'burica',
#  'pacific grove',
#  'kamenskoye',
#  'airai',
#  'sola',
#  'gold coast',
#  'rikitea',
#  'leningradskiy',
#  'cidreira',
#  'cherskiy',
#  'natal',
#  'sentyabrskiy',
#  'puerto ayora',
#  'constitucion',
#  'jamestown',
#  'byron bay',
#  'nizhneyansk',
#  'mataura',
#  'sorong',
#  'blackwater',
#  'upernavik',
#  'amboasary',
#  'nha trang',
#  'strathmore',
#  'san vicente',
#  'bilma',
#  'barinas',
#  'souillac',
#  'tuktoyaktuk',
#  'nanortalik',
#  'torbay',
#  'zhigansk',
#  'cafarnaum',
#  'torres',
#  'araouane',
#  'merauke',
#  'bluff',
#  'bentiu',
#  'hervey bay',
#  'elko',
#  'port blair',
#  'griffith',
#  'isangel',
#  'longyearbyen',
#  'upata',
#  'barmer',
#  'araripina',
#  'kokopo',
#  'port alfred',
#  'lasa',
#  'kuala terengganu',
#  'attawapiskat',
#  'flinders',
#  'saldanha',
#  'faanui',
#  'toora-khem',
#  'belomorsk',
#  'yingkou',
#  'tautira',
#  'hovd',
#  'makakilo city',
#  'manggar',
#  'butaritari',
#  'nantucket',
#  'mys shmidta',
#  'izazi',
#  'tsihombe',
#  'usinsk',
#  'severo-kurilsk',
#  'broken hill',
#  'safaga',
#  'hermanus',
#  'yerbogachen',
#  'antsohihy',
#  'ribeira grande',
#  'avarua',
#  'privas',
#  'fermoy',
#  'bud',
#  'bethel',
#  'lacombe',
#  'itoman',
#  'codrington',
#  'banmo',
#  'muroto',
#  'yellowknife',
#  'iqaluit',
#  'mount isa',
#  'cayenne',
#  'hobart',
#  'soyo',
#  'la orilla',
#  'buala',
#  'marfino',
#  'port hawkesbury',
#  'neryungri',
#  'amderma',
#  'verkhoyansk',
#  'lethem',
#  'ponta do sol',
#  'chokurdakh',
#  'los llanos de aridane',
#  'antalaha',
#  'tuatapere',
#  'broome',
#  'jardim',
#  'kurilsk',
#  'saint-augustin',
#  'gombe',
#  'dzhusaly',
#  'kavieng',
#  'vaitupu',
#  'rio gallegos',
#  'riyadh',
#  'cockburn harbour',
#  'pitimbu',
#  'tir pol',
#  'grand gaube',
#  'deputatskiy',
#  'san patricio',
#  'east london',
#  'sitrah',
#  'mecca',
#  'kaitangata',
#  'siilinjarvi',
#  'portland',
#  'luderitz',
#  'carnarvon',
#  'vostok',
#  'balkhash',
#  'naze',
#  'klaksvik',
#  'westport',
#  'guaruja',
#  'iringa',
#  'belushya guba',
#  'mouila',
#  'alice town',
#  'yeppoon',
#  'san quintin',
#  'udachnyy',
#  'umzimvubu',
#  'haines junction',
#  'alofi',
#  'kahului',
#  'arman',
#  'mixtepec',
#  'havoysund',
#  'sambava',
#  'ust-kamchatsk',
#  'baoqing',
#  'lebu',
#  'pimenta bueno',
#  'fushun',
#  'golyshmanovo',
#  'gorno-chuyskiy',
#  'mayo',
#  'oktyabrskoye',
#  'provideniya',
#  'narsaq',
#  'kruisfontein',
#  'halifax',
#  'ajdabiya',
#  'victoria',
#  'mount gambier',
#  'sao luis do quitunde',
#  'mar del plata',
#  'swellendam',
#  'kegayli',
#  'pingshan',
#  'port lincoln',
#  'muisne',
#  'kodiak',
#  'aswan',
#  'huambo',
#  'merritt island',
#  'sao filipe',
#  'arraial do cabo',
#  'luanda',
#  'quelimane',
#  'marsaxlokk',
#  'marcona',
#  'wewak',
#  'tual',
#  'dondukovskaya',
#  'solwezi',
#  'paamiut',
#  'avera',
#  'lubyany',
#  'kudahuvadhoo',
#  'lisakovsk',
#  'half moon bay',
#  'wanning',
#  'bathsheba',
#  'lichtenburg',
#  'sorvag',
#  'coahuayana',
#  'batagay',
#  'roald',
#  'havre-saint-pierre',
#  'yulara',
#  'talnakh',
#  'goianesia',
#  'bengkulu',
#  'sechura',
#  'imeni poliny osipenko',
#  'limon',
#  'ostrovnoy',
#  'puri',
#  'cairns',
#  'shimoda',
#  'moron',
#  'kalabo',
#  'caravelas',
#  'comodoro rivadavia',
#  'micheweni',
#  'port hardy',
#  'grindavik',
#  'kulhudhuffushi',
#  'guadalupe y calvo',
#  'ahuimanu',
#  'thompson',
#  'barrow',
#  'asau',
#  'coihaique',
#  'padang',
#  'castro',
#  'mancio lima',
#  'khuzdar',
#  'berlevag',
#  'awjilah',
#  'buqayq',
#  'college',
#  'ivanava',
#  'sao francisco do sul',
#  'ilulissat',
#  'warqla',
#  'mitsamiouli',
#  'jega',
#  'cua',
#  'hamilton',
#  'yuancheng',
#  'prince rupert',
#  'geraldton',
#  'wladyslawowo',
#  'ancud',
#  'sorland',
#  'fonte boa',
#  'krasnoselkup',
#  'ibra',
#  'belmonte',
#  'sobolevo',
#  'rocha',
#  'la ronge',
#  'sawtell',
#  'zyryanka',
#  'marawi',
#  'samusu',
#  'biloela',
#  'abu samrah',
#  'leh',
#  'furtwangen',
#  'cuiluan',
#  'suixi',
#  'shahreza',
#  'kapit',
#  'songea',
#  'tawkar',
#  'tiksi',
#  'te anau',
#  'kasongo',
#  'manyana',
#  'ugoofaaru',
#  'puerto ayacucho',
#  'tanggu',
#  'kiama',
#  'yar-sale',
#  'dipkarpaz',
#  'bacolod',
#  'wajir',
#  'san ignacio de sabaneta',
#  'nara',
#  'gayeri',
#  'isiro',
#  'biltine',
#  'wamba',
#  'challans',
#  'pucallpa',
#  'orthez',
#  'dolinsk',
#  'bintulu',
#  'vila franca do campo',
#  'sao domingos',
#  'kangaatsiaq',
#  'najran',
#  'chicama',
#  'chumikan',
#  'vieques',
#  'itagiba',
#  'turukhansk',
#  'clyde river',
#  'haapiti',
#  'moose factory',
#  'burmakino',
#  'emerald',
#  'coronado',
#  'ossora',
#  'ust-kuyga',
#  'belaya gora',
#  'vestmannaeyjar',
#  'samarai',
#  'tumannyy',
#  'tazovskiy',
#  'malakal',
#  'jawala mukhi',
#  'jiangyou',
#  'fagernes',
#  'tibati',
#  'coquimbo',
#  'scarborough',
#  'batagay-alyta',
#  'marienburg',
#  'vanimo',
#  'strelka',
#  'hasaki',
#  'tocache',
#  'finnsnes',
#  'teya',
#  'honiara',
#  'duldurga',
#  'green valley',
#  'salinopolis',
#  'bolungarvik',
#  'shingu',
#  'jalu',
#  'hay river',
#  'rawson',
#  'trelew',
#  'bandarbeyla',
#  'sangar',
#  'ewa beach',
#  'salalah',
#  'keningau',
#  'temba',
#  'montlucon',
#  'mendi',
#  'cervo',
#  'bowen',
#  'muros',
#  'chemal',
#  'gizo',
#  'zanjan',
#  'seoul',
#  'lakes entrance',
#  'harnosand',
#  'marsabit',
#  'ocampo',
#  'khatanga',
#  'esperance',
#  'takoradi',
#  'dossor',
#  'ambulu',
#  'hofn',
#  'hobyo',
#  'andarab',
#  'nalut',
#  'abu dhabi',
#  'grand-santi',
#  'sandane',
#  'palatka',
#  'auki',
#  'harper',
#  'puerto escondido',
#  'skjervoy',
#  'cercal',
#  'dicabisagan',
#  'karaton',
#  'kavaratti',
#  'laguna',
#  'mehamn',
#  'lata',
#  'boldumsaz',
#  'clairmont',
#  'maniitsoq',
#  'camacha',
#  'saint-pierre',
#  'xining',
#  'sindand',
#  'jipijapa',
#  'de-kastri',
#  'cabedelo',
#  'yurla',
#  'yol',
#  'benicia',
#  'barela',
#  'qingquan',
#  'singaraja',
#  'mehran',
#  'srednekolymsk',
#  'smithers',
#  'itarema',
#  'havre',
#  'allanmyo',
#  'ambon',
#  'lashio',
#  'guerrero negro',
#  'fortuna',
#  'bridlington',
#  'inhambane',
#  'bell ville',
#  'ratzeburg',
#  'cabo san lucas',
#  'kanniyakumari',
#  'nambour',
#  'san lorenzo',
#  'vila velha',
#  'espanola',
#  'guider',
#  'zhanakorgan',
#  'lewistown',
#  'aykhal',
#  'corinto',
#  'xam nua',
#  'terrace',
#  'neiafu',
#  'karaul',
#  'fairbanks',
#  'hami',
#  'rypefjord',
#  'zlatoustovsk',
#  'ruidoso',
#  'oudtshoorn',
#  'pevek',
#  'sitka',
#  'dedovichi',
#  'ejido',
#  'husavik',
#  'revda',
#  'altamira',
#  'mugur-aksy',
#  'kloulklubed',
#  'whitehorse',
#  'tura',
#  'banjar',
#  'tabou',
#  'reconquista',
#  'saleaula',
#  'kerema',
#  'baruun-urt',
#  'klyuchi',
#  'segrate',
#  'velsk',
#  'zhoucheng',
#  'yanam',
#  'pinotepa nacional',
#  'tabulbah',
#  'bilibino',
#  'nagar karnul',
#  'dunedin',
#  'urucui',
#  'faya',
#  'sabang',
#  'meiganga',
#  'barra mansa',
#  'chalmette',
#  'marabba',
#  'bac lieu',
#  'yanliang',
#  'pilos',
#  'samalaeulu',
#  'conde',
#  'taoudenni',
#  'oistins',
#  'crab hill',
#  'cheremukhovo',
#  'dingle',
#  'jabinyanah',
#  'palmer',
#  'vallecillo',
#  'okhotsk',
#  'leshukonskoye',
#  'dakar',
#  'abbotsford',
#  'igrim',
#  'formoso do araguaia',
#  'teahupoo',
#  'fort saint james',
#  'kirakira',
#  'acurenam',
#  'la cruz',
#  'maputo',
#  'almora',
#  'bahia blanca',
#  'chauk',
#  'cheuskiny',
#  'norman wells',
#  'muscat',
#  'deulgaon raja',
#  'beloha',
#  'katsuura',
#  'pemangkat',
#  'maridi',
#  'waingapu',
#  'banting',
#  'gamba',
#  'meulaboh',
#  'mahon',
#  'north marysville',
#  'darnah',
#  'tsabong',
#  'galveston',
#  'lorengau',
#  'denpasar',
#  'khonuu',
#  'paracuru',
#  'tevaitoa',
#  'brae',
#  'aquiraz',
#  'margate',
#  'sardarshahr',
#  'russell',
#  'picton',
#  'batemans bay',
#  'chifeng',
#  'kysyl-syr',
#  'ciudad guayana',
#  'homer',
#  'walvis bay',
#  'bardiyah',
#  'nome',
#  'maraa',
#  'sinnamary',
#  'nioaque',
#  'kabinda',
#  'hsinchu',
#  'palabuhanratu',
#  'kawalu',
#  'roebourne',
#  'nguiu',
#  'bartica',
#  'gigmoto',
#  'myitkyina',
#  'aizkraukle',
#  'filingue',
#  'port-cartier',
#  'tunxi',
#  'cap malheureux',
#  'poltava',
#  'jinchang',
#  'sohag',
#  'chara',
#  'troitsko-pechorsk',
#  'mahanoro',
#  'chapleau',
#  'yafran',
#  'bafoulabe',
#  'daxian',
#  'ormara',
#  'xichang',
#  'mlonggo',
#  'bethlehem',
#  'umm lajj',
#  'punta alta',
#  'tsienyane',
#  'betioky',
#  'birin',
#  'kota kinabalu',
#  'yantzaza',
#  'marystown',
#  'den helder',
#  'gobabis',
#  'cordoba',
#  'anchorage',
#  'henties bay',
#  'port augusta',
#  'high rock',
#  'nouakchott',
#  'ocos',
#  'oeiras do para',
#  'auburn',
#  'parrita',
#  'kharovsk',
#  'kununurra',
#  'ukiah',
#  'fare',
#  'ouadda',
#  'praya',
#  'lindi',
#  'praia da vitoria',
#  'pisco',
#  'ambam',
#  'pasighat',
#  'krasnoye',
#  'acarau',
#  'magistralnyy',
#  'thayetmyo',
#  'dudinka',
#  'muswellbrook',
#  'mandalgovi',
#  'constantine',
#  'lodeynoye pole',
#  'hualmay',
#  'maragogi',
#  'linchuan',
#  'luchegorsk',
#  'namibe',
#  'sanbu',
#  'nemuro',
#  'saint-junien',
#  'otuzco',
#  'nadym',
#  'baykit',
#  'batticaloa',
#  'montepuez',
#  'harlingen',
#  'cassilandia',
#  'rondonopolis',
#  'valparaiso',
#  'wasilla',
#  'ust-nera',
#  'mandla',
#  'nachingwea',
#  'ciudad bolivar',
#  'karamay',
#  'xuddur',
#  'mendoza',
#  'lolua',
#  'anadyr',
#  'cockburn town',
#  'louisbourg',
#  'campbell river',
#  'eidsvag',
#  'kendari',
#  'pangnirtung',
#  'ladario',
#  'melita',
#  'bairnsdale',
#  'tarudant',
#  'kinablangan',
#  'ambilobe',
#  'along',
#  'butembo',
#  'sivas',
#  'umea',
#  'karratha',
#  'minab',
#  'saint-georges',
#  'kargasok',
#  'ridgecrest',
#  'entebbe',
#  'meadow lake',
#  'santa rosalia',
#  'mayabon',
#  'atamanovka',
#  'tuyen quang',
#  'lusambo',
#  'alexandria',
#  'terney',
#  'fernandopolis',
#  'marratxi',
#  'mondeville',
#  'belyy yar',
#  'ler',
#  'kamaishi',
#  'tarboro',
#  'andevoranto',
#  'palmares do sul',
#  'vibo valentia',
#  'san juan',
#  'moree',
#  'beyneu',
#  'tessalit',
#  'serik',
#  'teguldet',
#  'beira',
#  'borogontsy',
#  'kyren',
#  'gat',
#  'dharchula']

# %%
city_data = []

record_count = 1
set_count = 1

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | lavrentiya
# Processing Record 2 of Set 1 | aklavik
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | buraydah
# Processing Record 6 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 1 | mahebourg
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | kalmunai
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | nouadhibou
# Processing Record 15 of Set 1 | chuy
# Processing Record 16 of Set 1 | lompoc
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | basco
# Processing Record 22 of Set 1 | malatya
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | binzhou
# Processing Record 25 of Set 1 | methoni
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | vao
# Processing Record 29 of Set 1 | saint george
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | abha
# Processing Record 32 of Set 1 | tambilil
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | beringovskiy
# Processing Record 42 of Set 1 | ixtapa
# Processing Record 43 of Set 1 | san policarpo
# Processing Record 44 of Set 1 | caconde
# Processing Record 45 of Set 1 | bambous virieux
# Processing Record 46 of Set 1 | san cristobal
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | itaituba
# Processing Record 49 of Set 1 | burica
# City not found. Skipping...
# Processing Record 50 of Set 1 | pacific grove
# Processing Record 1 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 2 | airai
# Processing Record 3 of Set 2 | sola
# Processing Record 4 of Set 2 | gold coast
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | leningradskiy
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | natal
# Processing Record 10 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | constitucion
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | byron bay
# Processing Record 15 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | sorong
# Processing Record 18 of Set 2 | blackwater
# Processing Record 19 of Set 2 | upernavik
# Processing Record 20 of Set 2 | amboasary
# Processing Record 21 of Set 2 | nha trang
# Processing Record 22 of Set 2 | strathmore
# Processing Record 23 of Set 2 | san vicente
# Processing Record 24 of Set 2 | bilma
# Processing Record 25 of Set 2 | barinas
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | torbay
# Processing Record 30 of Set 2 | zhigansk
# Processing Record 31 of Set 2 | cafarnaum
# Processing Record 32 of Set 2 | torres
# Processing Record 33 of Set 2 | araouane
# Processing Record 34 of Set 2 | merauke
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | bentiu
# Processing Record 37 of Set 2 | hervey bay
# Processing Record 38 of Set 2 | elko
# Processing Record 39 of Set 2 | port blair
# Processing Record 40 of Set 2 | griffith
# Processing Record 41 of Set 2 | isangel
# Processing Record 42 of Set 2 | longyearbyen
# Processing Record 43 of Set 2 | upata
# Processing Record 44 of Set 2 | barmer
# Processing Record 45 of Set 2 | araripina
# Processing Record 46 of Set 2 | kokopo
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | lasa
# Processing Record 49 of Set 2 | kuala terengganu
# Processing Record 50 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 3 | flinders
# Processing Record 2 of Set 3 | saldanha
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | toora-khem
# Processing Record 5 of Set 3 | belomorsk
# Processing Record 6 of Set 3 | yingkou
# Processing Record 7 of Set 3 | tautira
# Processing Record 8 of Set 3 | hovd
# Processing Record 9 of Set 3 | makakilo city
# Processing Record 10 of Set 3 | manggar
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | nantucket
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | izazi
# Processing Record 15 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 3 | usinsk
# Processing Record 17 of Set 3 | severo-kurilsk
# Processing Record 18 of Set 3 | broken hill
# Processing Record 19 of Set 3 | safaga
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | yerbogachen
# Processing Record 22 of Set 3 | antsohihy
# Processing Record 23 of Set 3 | ribeira grande
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | privas
# Processing Record 26 of Set 3 | fermoy
# Processing Record 27 of Set 3 | bud
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | lacombe
# Processing Record 30 of Set 3 | itoman
# Processing Record 31 of Set 3 | codrington
# Processing Record 32 of Set 3 | banmo
# City not found. Skipping...
# Processing Record 33 of Set 3 | muroto
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | iqaluit
# Processing Record 36 of Set 3 | mount isa
# Processing Record 37 of Set 3 | cayenne
# Processing Record 38 of Set 3 | hobart
# Processing Record 39 of Set 3 | soyo
# Processing Record 40 of Set 3 | la orilla
# Processing Record 41 of Set 3 | buala
# Processing Record 42 of Set 3 | marfino
# Processing Record 43 of Set 3 | port hawkesbury
# Processing Record 44 of Set 3 | neryungri
# Processing Record 45 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 3 | verkhoyansk
# Processing Record 47 of Set 3 | lethem
# Processing Record 48 of Set 3 | ponta do sol
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | los llanos de aridane
# Processing Record 1 of Set 4 | antalaha
# Processing Record 2 of Set 4 | tuatapere
# Processing Record 3 of Set 4 | broome
# Processing Record 4 of Set 4 | jardim
# Processing Record 5 of Set 4 | kurilsk
# Processing Record 6 of Set 4 | saint-augustin
# Processing Record 7 of Set 4 | gombe
# Processing Record 8 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 4 | kavieng
# Processing Record 10 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 4 | rio gallegos
# Processing Record 12 of Set 4 | riyadh
# Processing Record 13 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 14 of Set 4 | pitimbu
# Processing Record 15 of Set 4 | tir pol
# City not found. Skipping...
# Processing Record 16 of Set 4 | grand gaube
# Processing Record 17 of Set 4 | deputatskiy
# Processing Record 18 of Set 4 | san patricio
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | sitrah
# Processing Record 21 of Set 4 | mecca
# Processing Record 22 of Set 4 | kaitangata
# Processing Record 23 of Set 4 | siilinjarvi
# Processing Record 24 of Set 4 | portland
# Processing Record 25 of Set 4 | luderitz
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | vostok
# Processing Record 28 of Set 4 | balkhash
# Processing Record 29 of Set 4 | naze
# Processing Record 30 of Set 4 | klaksvik
# Processing Record 31 of Set 4 | westport
# Processing Record 32 of Set 4 | guaruja
# Processing Record 33 of Set 4 | iringa
# Processing Record 34 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 4 | mouila
# Processing Record 36 of Set 4 | alice town
# Processing Record 37 of Set 4 | yeppoon
# Processing Record 38 of Set 4 | san quintin
# Processing Record 39 of Set 4 | udachnyy
# Processing Record 40 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 4 | haines junction
# Processing Record 42 of Set 4 | alofi
# Processing Record 43 of Set 4 | kahului
# Processing Record 44 of Set 4 | arman
# Processing Record 45 of Set 4 | mixtepec
# City not found. Skipping...
# Processing Record 46 of Set 4 | havoysund
# Processing Record 47 of Set 4 | sambava
# Processing Record 48 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 4 | baoqing
# Processing Record 50 of Set 4 | lebu
# Processing Record 1 of Set 5 | pimenta bueno
# Processing Record 2 of Set 5 | fushun
# Processing Record 3 of Set 5 | golyshmanovo
# Processing Record 4 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 5 of Set 5 | mayo
# Processing Record 6 of Set 5 | oktyabrskoye
# Processing Record 7 of Set 5 | provideniya
# Processing Record 8 of Set 5 | narsaq
# Processing Record 9 of Set 5 | kruisfontein
# Processing Record 10 of Set 5 | halifax
# Processing Record 11 of Set 5 | ajdabiya
# Processing Record 12 of Set 5 | victoria
# Processing Record 13 of Set 5 | mount gambier
# Processing Record 14 of Set 5 | sao luis do quitunde
# Processing Record 15 of Set 5 | mar del plata
# Processing Record 16 of Set 5 | swellendam
# Processing Record 17 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 5 | pingshan
# Processing Record 19 of Set 5 | port lincoln
# Processing Record 20 of Set 5 | muisne
# Processing Record 21 of Set 5 | kodiak
# Processing Record 22 of Set 5 | aswan
# Processing Record 23 of Set 5 | huambo
# Processing Record 24 of Set 5 | merritt island
# Processing Record 25 of Set 5 | sao filipe
# Processing Record 26 of Set 5 | arraial do cabo
# Processing Record 27 of Set 5 | luanda
# Processing Record 28 of Set 5 | quelimane
# Processing Record 29 of Set 5 | marsaxlokk
# Processing Record 30 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 5 | wewak
# Processing Record 32 of Set 5 | tual
# Processing Record 33 of Set 5 | dondukovskaya
# Processing Record 34 of Set 5 | solwezi
# Processing Record 35 of Set 5 | paamiut
# Processing Record 36 of Set 5 | avera
# Processing Record 37 of Set 5 | lubyany
# Processing Record 38 of Set 5 | kudahuvadhoo
# Processing Record 39 of Set 5 | lisakovsk
# Processing Record 40 of Set 5 | half moon bay
# Processing Record 41 of Set 5 | wanning
# Processing Record 42 of Set 5 | bathsheba
# Processing Record 43 of Set 5 | lichtenburg
# Processing Record 44 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 5 | coahuayana
# Processing Record 46 of Set 5 | batagay
# Processing Record 47 of Set 5 | roald
# Processing Record 48 of Set 5 | havre-saint-pierre
# Processing Record 49 of Set 5 | yulara
# Processing Record 50 of Set 5 | talnakh
# Processing Record 1 of Set 6 | goianesia
# Processing Record 2 of Set 6 | bengkulu
# Processing Record 3 of Set 6 | sechura
# Processing Record 4 of Set 6 | imeni poliny osipenko
# Processing Record 5 of Set 6 | limon
# Processing Record 6 of Set 6 | ostrovnoy
# Processing Record 7 of Set 6 | puri
# Processing Record 8 of Set 6 | cairns
# Processing Record 9 of Set 6 | shimoda
# Processing Record 10 of Set 6 | moron
# Processing Record 11 of Set 6 | kalabo
# Processing Record 12 of Set 6 | caravelas
# Processing Record 13 of Set 6 | comodoro rivadavia
# Processing Record 14 of Set 6 | micheweni
# Processing Record 15 of Set 6 | port hardy
# Processing Record 16 of Set 6 | grindavik
# Processing Record 17 of Set 6 | kulhudhuffushi
# Processing Record 18 of Set 6 | guadalupe y calvo
# Processing Record 19 of Set 6 | ahuimanu
# Processing Record 20 of Set 6 | thompson
# Processing Record 21 of Set 6 | barrow
# Processing Record 22 of Set 6 | asau
# Processing Record 23 of Set 6 | coihaique
# Processing Record 24 of Set 6 | padang
# Processing Record 25 of Set 6 | castro
# Processing Record 26 of Set 6 | mancio lima
# Processing Record 27 of Set 6 | khuzdar
# Processing Record 28 of Set 6 | berlevag
# Processing Record 29 of Set 6 | awjilah
# Processing Record 30 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 31 of Set 6 | college
# Processing Record 32 of Set 6 | ivanava
# Processing Record 33 of Set 6 | sao francisco do sul
# Processing Record 34 of Set 6 | ilulissat
# Processing Record 35 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 6 | mitsamiouli
# Processing Record 37 of Set 6 | jega
# Processing Record 38 of Set 6 | cua
# Processing Record 39 of Set 6 | hamilton
# Processing Record 40 of Set 6 | yuancheng
# Processing Record 41 of Set 6 | prince rupert
# Processing Record 42 of Set 6 | geraldton
# Processing Record 43 of Set 6 | wladyslawowo
# Processing Record 44 of Set 6 | ancud
# Processing Record 45 of Set 6 | sorland
# Processing Record 46 of Set 6 | fonte boa
# Processing Record 47 of Set 6 | krasnoselkup
# Processing Record 48 of Set 6 | ibra
# Processing Record 49 of Set 6 | belmonte
# Processing Record 50 of Set 6 | sobolevo
# Processing Record 1 of Set 7 | rocha
# Processing Record 2 of Set 7 | la ronge
# Processing Record 3 of Set 7 | sawtell
# Processing Record 4 of Set 7 | zyryanka
# Processing Record 5 of Set 7 | marawi
# Processing Record 6 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 7 | biloela
# Processing Record 8 of Set 7 | abu samrah
# Processing Record 9 of Set 7 | leh
# Processing Record 10 of Set 7 | furtwangen
# Processing Record 11 of Set 7 | cuiluan
# Processing Record 12 of Set 7 | suixi
# Processing Record 13 of Set 7 | shahreza
# Processing Record 14 of Set 7 | kapit
# Processing Record 15 of Set 7 | songea
# Processing Record 16 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 17 of Set 7 | tiksi
# Processing Record 18 of Set 7 | te anau
# Processing Record 19 of Set 7 | kasongo
# Processing Record 20 of Set 7 | manyana
# Processing Record 21 of Set 7 | ugoofaaru
# Processing Record 22 of Set 7 | puerto ayacucho
# Processing Record 23 of Set 7 | tanggu
# Processing Record 24 of Set 7 | kiama
# Processing Record 25 of Set 7 | yar-sale
# Processing Record 26 of Set 7 | dipkarpaz
# City not found. Skipping...
# Processing Record 27 of Set 7 | bacolod
# Processing Record 28 of Set 7 | wajir
# Processing Record 29 of Set 7 | san ignacio de sabaneta
# City not found. Skipping...
# Processing Record 30 of Set 7 | nara
# Processing Record 31 of Set 7 | gayeri
# Processing Record 32 of Set 7 | isiro
# Processing Record 33 of Set 7 | biltine
# Processing Record 34 of Set 7 | wamba
# Processing Record 35 of Set 7 | challans
# Processing Record 36 of Set 7 | pucallpa
# Processing Record 37 of Set 7 | orthez
# Processing Record 38 of Set 7 | dolinsk
# Processing Record 39 of Set 7 | bintulu
# Processing Record 40 of Set 7 | vila franca do campo
# Processing Record 41 of Set 7 | sao domingos
# Processing Record 42 of Set 7 | kangaatsiaq
# Processing Record 43 of Set 7 | najran
# Processing Record 44 of Set 7 | chicama
# Processing Record 45 of Set 7 | chumikan
# Processing Record 46 of Set 7 | vieques
# Processing Record 47 of Set 7 | itagiba
# Processing Record 48 of Set 7 | turukhansk
# Processing Record 49 of Set 7 | clyde river
# Processing Record 50 of Set 7 | haapiti
# Processing Record 1 of Set 8 | moose factory
# Processing Record 2 of Set 8 | burmakino
# Processing Record 3 of Set 8 | emerald
# Processing Record 4 of Set 8 | coronado
# Processing Record 5 of Set 8 | ossora
# Processing Record 6 of Set 8 | ust-kuyga
# Processing Record 7 of Set 8 | belaya gora
# Processing Record 8 of Set 8 | vestmannaeyjar
# Processing Record 9 of Set 8 | samarai
# Processing Record 10 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 8 | tazovskiy
# Processing Record 12 of Set 8 | malakal
# Processing Record 13 of Set 8 | jawala mukhi
# Processing Record 14 of Set 8 | jiangyou
# Processing Record 15 of Set 8 | fagernes
# Processing Record 16 of Set 8 | tibati
# Processing Record 17 of Set 8 | coquimbo
# Processing Record 18 of Set 8 | scarborough
# Processing Record 19 of Set 8 | batagay-alyta
# Processing Record 20 of Set 8 | marienburg
# Processing Record 21 of Set 8 | vanimo
# Processing Record 22 of Set 8 | strelka
# Processing Record 23 of Set 8 | hasaki
# Processing Record 24 of Set 8 | tocache
# Processing Record 25 of Set 8 | finnsnes
# Processing Record 26 of Set 8 | teya
# Processing Record 27 of Set 8 | honiara
# Processing Record 28 of Set 8 | duldurga
# Processing Record 29 of Set 8 | green valley
# Processing Record 30 of Set 8 | salinopolis
# Processing Record 31 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 8 | shingu
# Processing Record 33 of Set 8 | jalu
# Processing Record 34 of Set 8 | hay river
# Processing Record 35 of Set 8 | rawson
# Processing Record 36 of Set 8 | trelew
# Processing Record 37 of Set 8 | bandarbeyla
# Processing Record 38 of Set 8 | sangar
# Processing Record 39 of Set 8 | ewa beach
# Processing Record 40 of Set 8 | salalah
# Processing Record 41 of Set 8 | keningau
# Processing Record 42 of Set 8 | temba
# Processing Record 43 of Set 8 | montlucon
# Processing Record 44 of Set 8 | mendi
# Processing Record 45 of Set 8 | cervo
# Processing Record 46 of Set 8 | bowen
# Processing Record 47 of Set 8 | muros
# Processing Record 48 of Set 8 | chemal
# Processing Record 49 of Set 8 | gizo
# Processing Record 50 of Set 8 | zanjan
# Processing Record 1 of Set 9 | seoul
# Processing Record 2 of Set 9 | lakes entrance
# Processing Record 3 of Set 9 | harnosand
# Processing Record 4 of Set 9 | marsabit
# Processing Record 5 of Set 9 | ocampo
# Processing Record 6 of Set 9 | khatanga
# Processing Record 7 of Set 9 | esperance
# Processing Record 8 of Set 9 | takoradi
# Processing Record 9 of Set 9 | dossor
# Processing Record 10 of Set 9 | ambulu
# Processing Record 11 of Set 9 | hofn
# Processing Record 12 of Set 9 | hobyo
# Processing Record 13 of Set 9 | andarab
# City not found. Skipping...
# Processing Record 14 of Set 9 | nalut
# Processing Record 15 of Set 9 | abu dhabi
# Processing Record 16 of Set 9 | grand-santi
# Processing Record 17 of Set 9 | sandane
# Processing Record 18 of Set 9 | palatka
# Processing Record 19 of Set 9 | auki
# Processing Record 20 of Set 9 | harper
# Processing Record 21 of Set 9 | puerto escondido
# Processing Record 22 of Set 9 | skjervoy
# Processing Record 23 of Set 9 | cercal
# Processing Record 24 of Set 9 | dicabisagan
# Processing Record 25 of Set 9 | karaton
# Processing Record 26 of Set 9 | kavaratti
# Processing Record 27 of Set 9 | laguna
# Processing Record 28 of Set 9 | mehamn
# Processing Record 29 of Set 9 | lata
# Processing Record 30 of Set 9 | boldumsaz
# Processing Record 31 of Set 9 | clairmont
# Processing Record 32 of Set 9 | maniitsoq
# Processing Record 33 of Set 9 | camacha
# Processing Record 34 of Set 9 | saint-pierre
# Processing Record 35 of Set 9 | xining
# Processing Record 36 of Set 9 | sindand
# City not found. Skipping...
# Processing Record 37 of Set 9 | jipijapa
# Processing Record 38 of Set 9 | de-kastri
# Processing Record 39 of Set 9 | cabedelo
# Processing Record 40 of Set 9 | yurla
# Processing Record 41 of Set 9 | yol
# Processing Record 42 of Set 9 | benicia
# Processing Record 43 of Set 9 | barela
# Processing Record 44 of Set 9 | qingquan
# Processing Record 45 of Set 9 | singaraja
# Processing Record 46 of Set 9 | mehran
# Processing Record 47 of Set 9 | srednekolymsk
# Processing Record 48 of Set 9 | smithers
# Processing Record 49 of Set 9 | itarema
# Processing Record 50 of Set 9 | havre
# Processing Record 1 of Set 10 | allanmyo
# City not found. Skipping...
# Processing Record 2 of Set 10 | ambon
# Processing Record 3 of Set 10 | lashio
# Processing Record 4 of Set 10 | guerrero negro
# Processing Record 5 of Set 10 | fortuna
# Processing Record 6 of Set 10 | bridlington
# Processing Record 7 of Set 10 | inhambane
# Processing Record 8 of Set 10 | bell ville
# Processing Record 9 of Set 10 | ratzeburg
# Processing Record 10 of Set 10 | cabo san lucas
# Processing Record 11 of Set 10 | kanniyakumari
# Processing Record 12 of Set 10 | nambour
# Processing Record 13 of Set 10 | san lorenzo
# Processing Record 14 of Set 10 | vila velha
# Processing Record 15 of Set 10 | espanola
# Processing Record 16 of Set 10 | guider
# Processing Record 17 of Set 10 | zhanakorgan
# Processing Record 18 of Set 10 | lewistown
# Processing Record 19 of Set 10 | aykhal
# Processing Record 20 of Set 10 | corinto
# Processing Record 21 of Set 10 | xam nua
# Processing Record 22 of Set 10 | terrace
# Processing Record 23 of Set 10 | neiafu
# Processing Record 24 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 10 | fairbanks
# Processing Record 26 of Set 10 | hami
# Processing Record 27 of Set 10 | rypefjord
# Processing Record 28 of Set 10 | zlatoustovsk
# City not found. Skipping...
# Processing Record 29 of Set 10 | ruidoso
# Processing Record 30 of Set 10 | oudtshoorn
# Processing Record 31 of Set 10 | pevek
# Processing Record 32 of Set 10 | sitka
# Processing Record 33 of Set 10 | dedovichi
# Processing Record 34 of Set 10 | ejido
# Processing Record 35 of Set 10 | husavik
# Processing Record 36 of Set 10 | revda
# Processing Record 37 of Set 10 | altamira
# Processing Record 38 of Set 10 | mugur-aksy
# Processing Record 39 of Set 10 | kloulklubed
# Processing Record 40 of Set 10 | whitehorse
# Processing Record 41 of Set 10 | tura
# Processing Record 42 of Set 10 | banjar
# Processing Record 43 of Set 10 | tabou
# Processing Record 44 of Set 10 | reconquista
# Processing Record 45 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 10 | kerema
# Processing Record 47 of Set 10 | baruun-urt
# Processing Record 48 of Set 10 | klyuchi
# Processing Record 49 of Set 10 | segrate
# Processing Record 50 of Set 10 | velsk
# Processing Record 1 of Set 11 | zhoucheng
# Processing Record 2 of Set 11 | yanam
# Processing Record 3 of Set 11 | pinotepa nacional
# Processing Record 4 of Set 11 | tabulbah
# City not found. Skipping...
# Processing Record 5 of Set 11 | bilibino
# Processing Record 6 of Set 11 | nagar karnul
# Processing Record 7 of Set 11 | dunedin
# Processing Record 8 of Set 11 | urucui
# Processing Record 9 of Set 11 | faya
# Processing Record 10 of Set 11 | sabang
# Processing Record 11 of Set 11 | meiganga
# Processing Record 12 of Set 11 | barra mansa
# Processing Record 13 of Set 11 | chalmette
# Processing Record 14 of Set 11 | marabba
# Processing Record 15 of Set 11 | bac lieu
# Processing Record 16 of Set 11 | yanliang
# Processing Record 17 of Set 11 | pilos
# City not found. Skipping...
# Processing Record 18 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 11 | conde
# Processing Record 20 of Set 11 | taoudenni
# Processing Record 21 of Set 11 | oistins
# Processing Record 22 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 23 of Set 11 | cheremukhovo
# Processing Record 24 of Set 11 | dingle
# Processing Record 25 of Set 11 | jabinyanah
# Processing Record 26 of Set 11 | palmer
# Processing Record 27 of Set 11 | vallecillo
# Processing Record 28 of Set 11 | okhotsk
# Processing Record 29 of Set 11 | leshukonskoye
# Processing Record 30 of Set 11 | dakar
# Processing Record 31 of Set 11 | abbotsford
# Processing Record 32 of Set 11 | igrim
# Processing Record 33 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 34 of Set 11 | teahupoo
# Processing Record 35 of Set 11 | fort saint james
# Processing Record 36 of Set 11 | kirakira
# Processing Record 37 of Set 11 | acurenam
# Processing Record 38 of Set 11 | la cruz
# Processing Record 39 of Set 11 | maputo
# Processing Record 40 of Set 11 | almora
# Processing Record 41 of Set 11 | bahia blanca
# Processing Record 42 of Set 11 | chauk
# Processing Record 43 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 44 of Set 11 | norman wells
# Processing Record 45 of Set 11 | muscat
# Processing Record 46 of Set 11 | deulgaon raja
# Processing Record 47 of Set 11 | beloha
# Processing Record 48 of Set 11 | katsuura
# Processing Record 49 of Set 11 | pemangkat
# Processing Record 50 of Set 11 | maridi
# Processing Record 1 of Set 12 | waingapu
# Processing Record 2 of Set 12 | banting
# Processing Record 3 of Set 12 | gamba
# Processing Record 4 of Set 12 | meulaboh
# Processing Record 5 of Set 12 | mahon
# Processing Record 6 of Set 12 | north marysville
# City not found. Skipping...
# Processing Record 7 of Set 12 | darnah
# Processing Record 8 of Set 12 | tsabong
# Processing Record 9 of Set 12 | galveston
# Processing Record 10 of Set 12 | lorengau
# Processing Record 11 of Set 12 | denpasar
# Processing Record 12 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 12 | paracuru
# Processing Record 14 of Set 12 | tevaitoa
# Processing Record 15 of Set 12 | brae
# Processing Record 16 of Set 12 | aquiraz
# Processing Record 17 of Set 12 | margate
# Processing Record 18 of Set 12 | sardarshahr
# Processing Record 19 of Set 12 | russell
# Processing Record 20 of Set 12 | picton
# Processing Record 21 of Set 12 | batemans bay
# Processing Record 22 of Set 12 | chifeng
# Processing Record 23 of Set 12 | kysyl-syr
# Processing Record 24 of Set 12 | ciudad guayana
# Processing Record 25 of Set 12 | homer
# Processing Record 26 of Set 12 | walvis bay
# Processing Record 27 of Set 12 | bardiyah
# Processing Record 28 of Set 12 | nome
# Processing Record 29 of Set 12 | maraa
# Processing Record 30 of Set 12 | sinnamary
# Processing Record 31 of Set 12 | nioaque
# Processing Record 32 of Set 12 | kabinda
# Processing Record 33 of Set 12 | hsinchu
# Processing Record 34 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 12 | kawalu
# Processing Record 36 of Set 12 | roebourne
# Processing Record 37 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 12 | bartica
# Processing Record 39 of Set 12 | gigmoto
# Processing Record 40 of Set 12 | myitkyina
# Processing Record 41 of Set 12 | aizkraukle
# Processing Record 42 of Set 12 | filingue
# Processing Record 43 of Set 12 | port-cartier
# Processing Record 44 of Set 12 | tunxi
# City not found. Skipping...
# Processing Record 45 of Set 12 | cap malheureux
# Processing Record 46 of Set 12 | poltava
# Processing Record 47 of Set 12 | jinchang
# Processing Record 48 of Set 12 | sohag
# Processing Record 49 of Set 12 | chara
# Processing Record 50 of Set 12 | troitsko-pechorsk
# Processing Record 1 of Set 13 | mahanoro
# Processing Record 2 of Set 13 | chapleau
# Processing Record 3 of Set 13 | yafran
# Processing Record 4 of Set 13 | bafoulabe
# Processing Record 5 of Set 13 | daxian
# City not found. Skipping...
# Processing Record 6 of Set 13 | ormara
# Processing Record 7 of Set 13 | xichang
# Processing Record 8 of Set 13 | mlonggo
# Processing Record 9 of Set 13 | bethlehem
# Processing Record 10 of Set 13 | umm lajj
# Processing Record 11 of Set 13 | punta alta
# Processing Record 12 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 13 of Set 13 | betioky
# Processing Record 14 of Set 13 | birin
# Processing Record 15 of Set 13 | kota kinabalu
# Processing Record 16 of Set 13 | yantzaza
# Processing Record 17 of Set 13 | marystown
# Processing Record 18 of Set 13 | den helder
# Processing Record 19 of Set 13 | gobabis
# Processing Record 20 of Set 13 | cordoba
# Processing Record 21 of Set 13 | anchorage
# Processing Record 22 of Set 13 | henties bay
# Processing Record 23 of Set 13 | port augusta
# Processing Record 24 of Set 13 | high rock
# Processing Record 25 of Set 13 | nouakchott
# Processing Record 26 of Set 13 | ocos
# Processing Record 27 of Set 13 | oeiras do para
# Processing Record 28 of Set 13 | auburn
# Processing Record 29 of Set 13 | parrita
# Processing Record 30 of Set 13 | kharovsk
# Processing Record 31 of Set 13 | kununurra
# Processing Record 32 of Set 13 | ukiah
# Processing Record 33 of Set 13 | fare
# Processing Record 34 of Set 13 | ouadda
# Processing Record 35 of Set 13 | praya
# Processing Record 36 of Set 13 | lindi
# Processing Record 37 of Set 13 | praia da vitoria
# Processing Record 38 of Set 13 | pisco
# Processing Record 39 of Set 13 | ambam
# Processing Record 40 of Set 13 | pasighat
# Processing Record 41 of Set 13 | krasnoye
# Processing Record 42 of Set 13 | acarau
# Processing Record 43 of Set 13 | magistralnyy
# Processing Record 44 of Set 13 | thayetmyo
# Processing Record 45 of Set 13 | dudinka
# Processing Record 46 of Set 13 | muswellbrook
# Processing Record 47 of Set 13 | mandalgovi
# Processing Record 48 of Set 13 | constantine
# Processing Record 49 of Set 13 | lodeynoye pole
# Processing Record 50 of Set 13 | hualmay
# Processing Record 1 of Set 14 | maragogi
# Processing Record 2 of Set 14 | linchuan
# City not found. Skipping...
# Processing Record 3 of Set 14 | luchegorsk
# Processing Record 4 of Set 14 | namibe
# Processing Record 5 of Set 14 | sanbu
# Processing Record 6 of Set 14 | nemuro
# Processing Record 7 of Set 14 | saint-junien
# Processing Record 8 of Set 14 | otuzco
# Processing Record 9 of Set 14 | nadym
# Processing Record 10 of Set 14 | baykit
# Processing Record 11 of Set 14 | batticaloa
# Processing Record 12 of Set 14 | montepuez
# Processing Record 13 of Set 14 | harlingen
# Processing Record 14 of Set 14 | cassilandia
# Processing Record 15 of Set 14 | rondonopolis
# Processing Record 16 of Set 14 | valparaiso
# Processing Record 17 of Set 14 | wasilla
# Processing Record 18 of Set 14 | ust-nera
# Processing Record 19 of Set 14 | mandla
# Processing Record 20 of Set 14 | nachingwea
# Processing Record 21 of Set 14 | ciudad bolivar
# Processing Record 22 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 23 of Set 14 | xuddur
# Processing Record 24 of Set 14 | mendoza
# Processing Record 25 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 14 | anadyr
# Processing Record 27 of Set 14 | cockburn town
# Processing Record 28 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 14 | campbell river
# Processing Record 30 of Set 14 | eidsvag
# Processing Record 31 of Set 14 | kendari
# Processing Record 32 of Set 14 | pangnirtung
# Processing Record 33 of Set 14 | ladario
# Processing Record 34 of Set 14 | melita
# Processing Record 35 of Set 14 | bairnsdale
# Processing Record 36 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 14 | kinablangan
# Processing Record 38 of Set 14 | ambilobe
# Processing Record 39 of Set 14 | along
# Processing Record 40 of Set 14 | butembo
# Processing Record 41 of Set 14 | sivas
# Processing Record 42 of Set 14 | umea
# Processing Record 43 of Set 14 | karratha
# Processing Record 44 of Set 14 | minab
# Processing Record 45 of Set 14 | saint-georges
# Processing Record 46 of Set 14 | kargasok
# Processing Record 47 of Set 14 | ridgecrest
# Processing Record 48 of Set 14 | entebbe
# Processing Record 49 of Set 14 | meadow lake
# Processing Record 50 of Set 14 | santa rosalia
# Processing Record 1 of Set 15 | mayabon
# Processing Record 2 of Set 15 | atamanovka
# Processing Record 3 of Set 15 | tuyen quang
# Processing Record 4 of Set 15 | lusambo
# Processing Record 5 of Set 15 | alexandria
# Processing Record 6 of Set 15 | terney
# Processing Record 7 of Set 15 | fernandopolis
# Processing Record 8 of Set 15 | marratxi
# Processing Record 9 of Set 15 | mondeville
# Processing Record 10 of Set 15 | belyy yar
# Processing Record 11 of Set 15 | ler
# Processing Record 12 of Set 15 | kamaishi
# Processing Record 13 of Set 15 | tarboro
# Processing Record 14 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 15 of Set 15 | palmares do sul
# Processing Record 16 of Set 15 | vibo valentia
# Processing Record 17 of Set 15 | san juan
# Processing Record 18 of Set 15 | moree
# Processing Record 19 of Set 15 | beyneu
# Processing Record 20 of Set 15 | tessalit
# Processing Record 21 of Set 15 | serik
# Processing Record 22 of Set 15 | teguldet
# Processing Record 23 of Set 15 | beira
# Processing Record 24 of Set 15 | borogontsy
# Processing Record 25 of Set 15 | kyren
# Processing Record 26 of Set 15 | gat
# Processing Record 27 of Set 15 | dharchula
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Lavrentiya      RU  65.5833 -171.0000     23.27        71          16
# 1     Aklavik      CA  68.2191 -135.0107     34.52        93          90
# 2     Qaanaaq      GL  77.4840  -69.3632     31.69        98         100
# 3   Saskylakh      RU  71.9167  114.0833     16.77        93          98
# 4    Buraydah      SA  26.3260   43.9750     90.05        12           2
# 5   Mahebourg      MU -20.4081   57.7000     72.25        88          75
# 6   Busselton      AU -33.6500  115.3333     42.08        67          87
# 7  Bredasdorp      ZA -34.5322   20.0403     50.29        87          13
# 8    Kalmunai      LK   7.4167   81.8167     80.49        81         100
# 9        Hilo      US  19.7297 -155.0900     73.62        84          90
#
#    Wind Speed Current Description
# 0        3.83          few clouds
# 1       12.66     overcast clouds
# 2        7.43          light snow
# 3       10.45     overcast clouds
# 4        9.62           clear sky
# 5       13.80       broken clouds
# 6        3.58     overcast clouds
# 7        0.00          few clouds
# 8        5.46     overcast clouds
# 9        4.61          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

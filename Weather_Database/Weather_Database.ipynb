# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
cities
# Out:
# ['mezen',
#  'kourou',
#  'ushuaia',
#  'busselton',
#  'illoqqortoormiut',
#  'vaini',
#  'rikitea',
#  'sao filipe',
#  'jamestown',
#  'pontian kecil',
#  'khatanga',
#  'carnarvon',
#  'pevek',
#  'hobart',
#  'pocone',
#  'grasten',
#  'felidhoo',
#  'bredasdorp',
#  'lavrentiya',
#  'kapaa',
#  'hermanus',
#  'searcy',
#  'puerto ayora',
#  'nizhneyansk',
#  'lebu',
#  'general roca',
#  'cape town',
#  'butaritari',
#  'shelabolikha',
#  'ribeira grande',
#  'camocim',
#  'daru',
#  'yar-sale',
#  'hilo',
#  'masallatah',
#  'karratha',
#  'atuona',
#  'saint quentin',
#  'fort nelson',
#  'mana',
#  'ermoupolis',
#  'nurota',
#  'calama',
#  'skibbereen',
#  'faanui',
#  'bluff',
#  'mataura',
#  'shache',
#  'ankpa',
#  'izyaslav',
#  'la palma',
#  'port alfred',
#  'barrow',
#  'khilok',
#  'zharkent',
#  'ilulissat',
#  'fez',
#  'avarua',
#  'hasanabad',
#  'pachino',
#  'saint anthony',
#  'palmer',
#  'gamboma',
#  'east london',
#  'khash',
#  'new norfolk',
#  'totoro',
#  'faya',
#  'yulara',
#  'ipora',
#  'castro',
#  'nikolskoye',
#  'albany',
#  'padang',
#  'umzimvubu',
#  'tumannyy',
#  'belushya guba',
#  'lata',
#  'dikson',
#  'lagoa',
#  'tuktoyaktuk',
#  'saleaula',
#  'hithadhoo',
#  'los llanos de aridane',
#  'micomeseng',
#  'chokurdakh',
#  'norman wells',
#  'san policarpo',
#  'muzhi',
#  'san patricio',
#  'tiksi',
#  'qaanaaq',
#  'sorong',
#  'torbay',
#  'sentyabrskiy',
#  'sackville',
#  'provideniya',
#  'coachella',
#  'belmonte',
#  'voh',
#  'priargunsk',
#  'klaksvik',
#  'punta arenas',
#  'namibe',
#  'vostok',
#  'miandrivazo',
#  'koupela',
#  'harper',
#  'paine',
#  'bethel',
#  'yellowknife',
#  'phonhong',
#  'ustye',
#  'richards bay',
#  'dali',
#  'linxia',
#  'gat',
#  'bilibino',
#  'naron',
#  'san cristobal',
#  'huilong',
#  'barentsburg',
#  'lazaro cardenas',
#  'najran',
#  'mys shmidta',
#  'grand centre',
#  'brawley',
#  'koulikoro',
#  'constitucion',
#  'utiroa',
#  'maniitsoq',
#  'venice',
#  'kulhudhuffushi',
#  'saldanha',
#  'george',
#  'port elizabeth',
#  'binzhou',
#  'mahebourg',
#  'quelimane',
#  'birao',
#  'west plains',
#  'pabrade',
#  'clyde river',
#  'yian',
#  'talnakh',
#  'itamarandiba',
#  'morganton',
#  'bolu',
#  'jasa tomic',
#  'longyearbyen',
#  'krasnoselkup',
#  'tasiilaq',
#  'ixtapa',
#  'turukhansk',
#  'souillac',
#  'chuy',
#  'srednekolymsk',
#  'shakawe',
#  'kaniama',
#  'ubinskoye',
#  'margate',
#  'kopeysk',
#  'caravelas',
#  'codrington',
#  'sao joao da barra',
#  'dryden',
#  'pisco',
#  'haysville',
#  'vaitupu',
#  'tocopilla',
#  'katsuura',
#  'amderma',
#  'inongo',
#  'patea',
#  'hasaki',
#  'mar del plata',
#  'banjarmasin',
#  'lufilufi',
#  'muros',
#  'smoky lake',
#  'georgetown',
#  'lolua',
#  'centralina',
#  'bequimao',
#  'bilma',
#  'leningradskiy',
#  'meteti',
#  'praya',
#  'kandiaro',
#  'nyagan',
#  'tomatlan',
#  'nanortalik',
#  'marcona',
#  'ilebo',
#  'fortuna',
#  'sarangani',
#  'macon',
#  'bengkulu',
#  'beringovskiy',
#  'kirakira',
#  'ancud',
#  'dire',
#  'aklavik',
#  'saint george',
#  'sur',
#  'nchelenge',
#  'sovetskiy',
#  'port augusta',
#  'maldonado',
#  'alofi',
#  'puli',
#  'pavilosta',
#  'townsville',
#  'ambon',
#  'santiago del estero',
#  'ahipara',
#  'cherskiy',
#  'pasighat',
#  'esperance',
#  'saskylakh',
#  'umm lajj',
#  'lake city',
#  'avera',
#  'saurimo',
#  'vestmannaeyjar',
#  'evensk',
#  'ponta do sol',
#  'lorengau',
#  'kaitangata',
#  'japura',
#  'halalo',
#  'cayenne',
#  'meulaboh',
#  'te anau',
#  'huarmey',
#  'grand river south east',
#  'yerbogachen',
#  'port keats',
#  'velsk',
#  'manjeshwar',
#  'cocobeach',
#  'port-cartier',
#  'krasnopillya',
#  'urumqi',
#  'mangai',
#  'talara',
#  'mabaruma',
#  'arraial do cabo',
#  'kodiak',
#  'taolanaro',
#  'tura',
#  'mongoumba',
#  'samusu',
#  'anadyr',
#  'placido de castro',
#  'artigas',
#  'aykhal',
#  'hovd',
#  'severo-kurilsk',
#  'jalgaon',
#  'vastervik',
#  'emerald',
#  'aksarka',
#  'selje',
#  'airai',
#  'nagina',
#  'thompson',
#  'slave lake',
#  'lazurne',
#  'portland',
#  'hofn',
#  'kearney',
#  'north bend',
#  'sangar',
#  'imbituba',
#  'sitka',
#  'aitape',
#  'kjollefjord',
#  'atambua',
#  'illintsi',
#  'geraldton',
#  'upernavik',
#  'lukavac',
#  'englehart',
#  'nishihara',
#  'puerto escondido',
#  'eenhana',
#  'bandarbeyla',
#  'batticaloa',
#  'morgan city',
#  'kampene',
#  'port hardy',
#  'bukene',
#  'port shepstone',
#  'port hedland',
#  'nouadhibou',
#  'tazovskiy',
#  'tuatapere',
#  'tabiauea',
#  'neuquen',
#  'naze',
#  'juneau',
#  'mareeba',
#  'dingle',
#  'shimoda',
#  'guerrero negro',
#  'itacare',
#  'bereda',
#  'mayskiy',
#  'zamora',
#  'valleyview',
#  'darhan',
#  'dergachi',
#  'salinopolis',
#  'bonthe',
#  'rijeka',
#  'donegal',
#  'goldsboro',
#  'vanimo',
#  'cockburn town',
#  'kisangani',
#  'ahar',
#  'grindavik',
#  'lompoc',
#  'port-gentil',
#  'laguna',
#  'marawi',
#  'kasongo',
#  'chimoio',
#  'suluova',
#  'rabat',
#  'bermeo',
#  'zelenoborskiy',
#  'saint-joseph',
#  'pyu',
#  'urcos',
#  'mirnyy',
#  'sola',
#  'nemuro',
#  'crotone',
#  'bogorodskoye',
#  'saint-philippe',
#  'tsihombe',
#  'tefe',
#  'paracuru',
#  'fuzhou',
#  'dubbo',
#  'wukari',
#  'ulladulla',
#  'verdalsora',
#  'palabuhanratu',
#  'rafai',
#  'gorom-gorom',
#  'khasan',
#  'ust-kulom',
#  'sechura',
#  'tabou',
#  'hoquiam',
#  'lodwar',
#  'adrar',
#  'ekuvukeni',
#  'severnyy-kospashskiy',
#  'muravlenko',
#  'orlik',
#  'semnan',
#  'asau',
#  'ampanihy',
#  'skibotn',
#  'monrovia',
#  'vila velha',
#  'vestmanna',
#  'tautira',
#  'antofagasta',
#  'tevaitoa',
#  'ulundi',
#  'batkovici',
#  'portpatrick',
#  'nargana',
#  'kabinda',
#  'nacala',
#  'akhtubinsk',
#  'ileza',
#  'desert hot springs',
#  'attawapiskat',
#  'chicama',
#  'ostrovnoy',
#  'aix-en-provence',
#  'pilao arcado',
#  'aksarayskiy',
#  'urdzhar',
#  'okhotsk',
#  'acapulco',
#  'ibra',
#  'novyy urengoy',
#  'notse',
#  'fare',
#  'kruisfontein',
#  'northam',
#  'ust-ilimsk',
#  'iqaluit',
#  'kharp',
#  'kloulklubed',
#  'kiruna',
#  'kaeo',
#  'byron bay',
#  'umba',
#  'kahului',
#  'saint-augustin',
#  'panguipulli',
#  'nantucket',
#  'bansko',
#  'kalabo',
#  'sidvokodvo',
#  'vani',
#  'luderitz',
#  'ballina',
#  'sergeyevka',
#  'kotma',
#  'santa eulalia del rio',
#  'chotebor',
#  'el mahalla el kubra',
#  'carballo',
#  'vangaindrano',
#  'de aar',
#  'plastun',
#  'niceville',
#  'rawson',
#  'bambanglipuro',
#  'sulangan',
#  'jamame',
#  'uarini',
#  'saint-pierre',
#  'kargasok',
#  'scottsbluff',
#  'waddan',
#  'plettenberg bay',
#  'peniche',
#  'walvis bay',
#  'madimba',
#  'baykit',
#  'hohhot',
#  'santa isabel do rio negro',
#  'petropavlovsk-kamchatskiy',
#  'leh',
#  'katangli',
#  'barela',
#  'paamiut',
#  'kijang',
#  'cabedelo',
#  'aras',
#  'sibolga',
#  'canayan',
#  'seoul',
#  'sorland',
#  'dalmatovo',
#  'mount isa',
#  'lahij',
#  'san roque',
#  'bambous virieux',
#  'ponta delgada',
#  'hami',
#  'merrill',
#  'ternovka',
#  'arman',
#  'gorontalo',
#  'narsaq',
#  'cabo san lucas',
#  'hirara',
#  'hobyo',
#  'ardakan',
#  'port said',
#  'salalah',
#  'dombarovskiy',
#  'honningsvag',
#  'blatnica',
#  'lacombe',
#  'tazmalt',
#  'camoapa',
#  'ryotsu',
#  'martapura',
#  'tarudant',
#  'rhyl',
#  'porto novo',
#  'oudtshoorn',
#  'buin',
#  'mogadishu',
#  'iralaya',
#  'flinders',
#  'yaan',
#  'aksha',
#  'santa rosa del sur',
#  'novorudnyy',
#  'talawdi',
#  'borama',
#  'gushikawa',
#  'tidore',
#  'tilichiki',
#  'ozgon',
#  'elko',
#  'kavieng',
#  'humberto de campos',
#  'san-pedro',
#  'qandala',
#  'husavik',
#  'farafangana',
#  'rome',
#  'komsomolskiy',
#  'satitoa',
#  'vezirkopru',
#  'barcelos',
#  'rohatyn',
#  'haines junction',
#  'dudinka',
#  'misratah',
#  'amurzet',
#  'victoria',
#  'kapoeta',
#  'praia',
#  'port lincoln',
#  'vihari',
#  'dubai',
#  'kashan',
#  'luganville',
#  'berlevag',
#  'teguldet',
#  'yerofey pavlovich',
#  'preston',
#  'betare oya',
#  'santa vitoria do palmar',
#  'chesma',
#  'swan hill',
#  'viedma',
#  'jalu',
#  'balaipungut',
#  'sotuta',
#  'xam nua',
#  'la paz',
#  'aberdeen',
#  'panguna',
#  'baghdad',
#  'deputatskiy',
#  'flin flon',
#  'carndonagh',
#  'bourail',
#  'carnduff',
#  'zacapoaxtla',
#  'surt',
#  'luanshya',
#  'changde',
#  'masunga',
#  'shengjin',
#  'tigil',
#  'maragogi',
#  'hualmay',
#  'ziniare',
#  'biggar',
#  'hamilton',
#  'oranjemund',
#  'banda aceh',
#  'marzuq',
#  'bokspits',
#  'melville',
#  'cidreira',
#  'sadiqabad',
#  'mildura',
#  'young',
#  'jati',
#  'chyhyryn',
#  'marsa matruh',
#  'olafsvik',
#  'kaoma',
#  'teya',
#  'aginskoye',
#  'thinadhoo',
#  'malyye derbety',
#  'holetown',
#  'sapucaia',
#  'grand-santi',
#  'isangel',
#  'serenje',
#  'ust-kuyga',
#  'ambunti',
#  'yumen',
#  'itaituba',
#  'clermont',
#  'navapur',
#  'josefina',
#  'ventspils',
#  'gopichettipalaiyam',
#  'leshukonskoye',
#  'longlac',
#  'vallenar',
#  'touros',
#  'zlobin',
#  'zhigansk',
#  'banjar',
#  'hambantota',
#  'broken hill',
#  'nome',
#  'lhokseumawe',
#  'shenjiamen',
#  'kalmunai',
#  'pitelino',
#  'dengzhou',
#  'noshiro',
#  'poltavka',
#  'pervomayskoye',
#  'esperanza',
#  'joaima',
#  'phalombe',
#  'bolonchen',
#  'port hawkesbury',
#  'guiratinga',
#  'mentok',
#  'vanavara',
#  'galle',
#  'barabinsk',
#  'devonport',
#  'okha',
#  'marrakesh',
#  'westport',
#  'edremit',
#  'las cruces',
#  'phangnga',
#  'capinzal',
#  'kurumkan',
#  'winton',
#  'qaqortoq',
#  'kungurtug',
#  'necochea',
#  'karauzyak',
#  'srbobran',
#  'brunswick',
#  'poum',
#  'tongliao',
#  'hornepayne',
#  'kindersley',
#  'iberia',
#  'vigrestad',
#  'mandapam',
#  'mandera',
#  'centreville',
#  'karamea',
#  'juybar',
#  'college',
#  'ostersund',
#  'coquimbo',
#  'dargaville',
#  'araouane',
#  'alice springs',
#  'cepu',
#  'sobolevo',
#  'apiai',
#  'waycross',
#  'veraval',
#  'kasongo-lunda',
#  'cerrito',
#  'abu kamal',
#  'manado',
#  'pangnirtung',
#  'kisiwani',
#  'puro',
#  'verkhnevilyuysk',
#  'pangoa',
#  'shitanjing',
#  'boldur',
#  'haimen',
#  'qasigiannguit',
#  'fulitun',
#  'woodstock',
#  'mouzakion',
#  'xiaoweizhai',
#  'rungata',
#  'beyneu',
#  'hede',
#  'wladyslawowo',
#  'khudumelapye',
#  'novyy urgal',
#  'khulo',
#  'el dorado',
#  'moussoro',
#  'hegang',
#  'suzun',
#  'baiyin',
#  'davila',
#  'nueva gerona',
#  'benguela',
#  'niamey',
#  'filadelfia',
#  'ketchenery',
#  'shellbrook',
#  'tiarei',
#  'paveh',
#  'novo aripuana',
#  'armacao dos buzios',
#  'labuhan',
#  'ormond beach',
#  'sioux lookout',
#  'santa fe',
#  'mitsamiouli',
#  'marshalltown',
#  'abalak',
#  'jega',
#  'arlit',
#  'fort myers beach',
#  'tawkar',
#  'bandundu',
#  'arroio grande',
#  'grand gaube',
#  'one hundred mile house',
#  'wanning',
#  'tanjong tokong',
#  'ust-kamchatsk',
#  'ossora',
#  'bargal',
#  'nguiu',
#  'cap malheureux',
#  'kropotkin',
#  'cerro de pasco',
#  'kuryk',
#  'kununurra',
#  'igrim',
#  'lasa',
#  'coihaique',
#  'babanusah',
#  'uvinza',
#  'elena',
#  'acarau',
#  'tigzirt',
#  'santa maria',
#  'tual',
#  'road town',
#  'gari',
#  'quatre cocos',
#  'nehe',
#  'plumbon',
#  'tosya',
#  'lahaina',
#  'manono',
#  'dunga bunga',
#  'ola',
#  'balakhta',
#  'bela vista',
#  'namatanai',
#  'houlung',
#  'macamic',
#  'singapore',
#  'sabang',
#  'caucel',
#  'rabo de peixe',
#  'hunchun',
#  'fairbanks',
#  'matay',
#  'inyonga',
#  'porecatu',
#  'aden',
#  'requena',
#  'lamesa',
#  'gamba',
#  'mandalgovi',
#  'baghmara',
#  'buala']

# %%
city_data = []

record_count = 1
set_count = 1

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mezen
# City not found. Skipping...
# Processing Record 2 of Set 1 | kourou
# City not found. Skipping...
# Processing Record 3 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 4 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | vaini
# City not found. Skipping...
# Processing Record 7 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 8 of Set 1 | sao filipe
# City not found. Skipping...
# Processing Record 9 of Set 1 | jamestown
# City not found. Skipping...
# Processing Record 10 of Set 1 | pontian kecil
# City not found. Skipping...
# Processing Record 11 of Set 1 | khatanga
# City not found. Skipping...
# Processing Record 12 of Set 1 | carnarvon
# City not found. Skipping...
# Processing Record 13 of Set 1 | pevek
# City not found. Skipping...
# Processing Record 14 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 15 of Set 1 | pocone
# City not found. Skipping...
# Processing Record 16 of Set 1 | grasten
# City not found. Skipping...
# Processing Record 17 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 18 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 19 of Set 1 | lavrentiya
# City not found. Skipping...
# Processing Record 20 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 21 of Set 1 | hermanus
# City not found. Skipping...
# Processing Record 22 of Set 1 | searcy
# City not found. Skipping...
# Processing Record 23 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 24 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 1 | lebu
# City not found. Skipping...
# Processing Record 26 of Set 1 | general roca
# City not found. Skipping...
# Processing Record 27 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 28 of Set 1 | butaritari
# City not found. Skipping...
# Processing Record 29 of Set 1 | shelabolikha
# City not found. Skipping...
# Processing Record 30 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 31 of Set 1 | camocim
# City not found. Skipping...
# Processing Record 32 of Set 1 | daru
# City not found. Skipping...
# Processing Record 33 of Set 1 | yar-sale
# City not found. Skipping...
# Processing Record 34 of Set 1 | hilo
# City not found. Skipping...
# Processing Record 35 of Set 1 | masallatah
# City not found. Skipping...
# Processing Record 36 of Set 1 | karratha
# City not found. Skipping...
# Processing Record 37 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 38 of Set 1 | saint quentin
# City not found. Skipping...
# Processing Record 39 of Set 1 | fort nelson
# City not found. Skipping...
# Processing Record 40 of Set 1 | mana
# City not found. Skipping...
# Processing Record 41 of Set 1 | ermoupolis
# City not found. Skipping...
# Processing Record 42 of Set 1 | nurota
# City not found. Skipping...
# Processing Record 43 of Set 1 | calama
# City not found. Skipping...
# Processing Record 44 of Set 1 | skibbereen
# City not found. Skipping...
# Processing Record 45 of Set 1 | faanui
# City not found. Skipping...
# Processing Record 46 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 47 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 48 of Set 1 | shache
# City not found. Skipping...
# Processing Record 49 of Set 1 | ankpa
# City not found. Skipping...
# Processing Record 50 of Set 1 | izyaslav
# City not found. Skipping...
# Processing Record 1 of Set 2 | la palma
# City not found. Skipping...
# Processing Record 2 of Set 2 | port alfred
# City not found. Skipping...
# Processing Record 3 of Set 2 | barrow
# City not found. Skipping...
# Processing Record 4 of Set 2 | khilok
# City not found. Skipping...
# Processing Record 5 of Set 2 | zharkent
# City not found. Skipping...
# Processing Record 6 of Set 2 | ilulissat
# City not found. Skipping...
# Processing Record 7 of Set 2 | fez
# City not found. Skipping...
# Processing Record 8 of Set 2 | avarua
# City not found. Skipping...
# Processing Record 9 of Set 2 | hasanabad
# City not found. Skipping...
# Processing Record 10 of Set 2 | pachino
# City not found. Skipping...
# Processing Record 11 of Set 2 | saint anthony
# City not found. Skipping...
# Processing Record 12 of Set 2 | palmer
# City not found. Skipping...
# Processing Record 13 of Set 2 | gamboma
# City not found. Skipping...
# Processing Record 14 of Set 2 | east london
# City not found. Skipping...
# Processing Record 15 of Set 2 | khash
# City not found. Skipping...
# Processing Record 16 of Set 2 | new norfolk
# City not found. Skipping...
# Processing Record 17 of Set 2 | totoro
# City not found. Skipping...
# Processing Record 18 of Set 2 | faya
# City not found. Skipping...
# Processing Record 19 of Set 2 | yulara
# City not found. Skipping...
# Processing Record 20 of Set 2 | ipora
# City not found. Skipping...
# Processing Record 21 of Set 2 | castro
# City not found. Skipping...
# Processing Record 22 of Set 2 | nikolskoye
# City not found. Skipping...
# Processing Record 23 of Set 2 | albany
# City not found. Skipping...
# Processing Record 24 of Set 2 | padang
# City not found. Skipping...
# Processing Record 25 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | lata
# City not found. Skipping...
# Processing Record 29 of Set 2 | dikson
# City not found. Skipping...
# Processing Record 30 of Set 2 | lagoa
# City not found. Skipping...
# Processing Record 31 of Set 2 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 32 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 2 | hithadhoo
# City not found. Skipping...
# Processing Record 34 of Set 2 | los llanos de aridane
# City not found. Skipping...
# Processing Record 35 of Set 2 | micomeseng
# City not found. Skipping...
# Processing Record 36 of Set 2 | chokurdakh
# City not found. Skipping...
# Processing Record 37 of Set 2 | norman wells
# City not found. Skipping...
# Processing Record 38 of Set 2 | san policarpo
# City not found. Skipping...
# Processing Record 39 of Set 2 | muzhi
# City not found. Skipping...
# Processing Record 40 of Set 2 | san patricio
# City not found. Skipping...
# Processing Record 41 of Set 2 | tiksi
# City not found. Skipping...
# Processing Record 42 of Set 2 | qaanaaq
# City not found. Skipping...
# Processing Record 43 of Set 2 | sorong
# City not found. Skipping...
# Processing Record 44 of Set 2 | torbay
# City not found. Skipping...
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | sackville
# City not found. Skipping...
# Processing Record 47 of Set 2 | provideniya
# City not found. Skipping...
# Processing Record 48 of Set 2 | coachella
# City not found. Skipping...
# Processing Record 49 of Set 2 | belmonte
# City not found. Skipping...
# Processing Record 50 of Set 2 | voh
# City not found. Skipping...
# Processing Record 1 of Set 3 | priargunsk
# City not found. Skipping...
# Processing Record 2 of Set 3 | klaksvik
# City not found. Skipping...
# Processing Record 3 of Set 3 | punta arenas
# City not found. Skipping...
# Processing Record 4 of Set 3 | namibe
# City not found. Skipping...
# Processing Record 5 of Set 3 | vostok
# City not found. Skipping...
# Processing Record 6 of Set 3 | miandrivazo
# City not found. Skipping...
# Processing Record 7 of Set 3 | koupela
# City not found. Skipping...
# Processing Record 8 of Set 3 | harper
# City not found. Skipping...
# Processing Record 9 of Set 3 | paine
# City not found. Skipping...
# Processing Record 10 of Set 3 | bethel
# City not found. Skipping...
# Processing Record 11 of Set 3 | yellowknife
# City not found. Skipping...
# Processing Record 12 of Set 3 | phonhong
# City not found. Skipping...
# Processing Record 13 of Set 3 | ustye
# City not found. Skipping...
# Processing Record 14 of Set 3 | richards bay
# City not found. Skipping...
# Processing Record 15 of Set 3 | dali
# City not found. Skipping...
# Processing Record 16 of Set 3 | linxia
# City not found. Skipping...
# Processing Record 17 of Set 3 | gat
# City not found. Skipping...
# Processing Record 18 of Set 3 | bilibino
# City not found. Skipping...
# Processing Record 19 of Set 3 | naron
# City not found. Skipping...
# Processing Record 20 of Set 3 | san cristobal
# City not found. Skipping...
# Processing Record 21 of Set 3 | huilong
# City not found. Skipping...
# Processing Record 22 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 3 | lazaro cardenas
# City not found. Skipping...
# Processing Record 24 of Set 3 | najran
# City not found. Skipping...
# Processing Record 25 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 3 | brawley
# City not found. Skipping...
# Processing Record 28 of Set 3 | koulikoro
# City not found. Skipping...
# Processing Record 29 of Set 3 | constitucion
# City not found. Skipping...
# Processing Record 30 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 3 | maniitsoq
# City not found. Skipping...
# Processing Record 32 of Set 3 | venice
# City not found. Skipping...
# Processing Record 33 of Set 3 | kulhudhuffushi
# City not found. Skipping...
# Processing Record 34 of Set 3 | saldanha
# City not found. Skipping...
# Processing Record 35 of Set 3 | george
# City not found. Skipping...
# Processing Record 36 of Set 3 | port elizabeth
# City not found. Skipping...
# Processing Record 37 of Set 3 | binzhou
# City not found. Skipping...
# Processing Record 38 of Set 3 | mahebourg
# City not found. Skipping...
# Processing Record 39 of Set 3 | quelimane
# City not found. Skipping...
# Processing Record 40 of Set 3 | birao
# City not found. Skipping...
# Processing Record 41 of Set 3 | west plains
# City not found. Skipping...
# Processing Record 42 of Set 3 | pabrade
# City not found. Skipping...
# Processing Record 43 of Set 3 | clyde river
# City not found. Skipping...
# Processing Record 44 of Set 3 | yian
# City not found. Skipping...
# Processing Record 45 of Set 3 | talnakh
# City not found. Skipping...
# Processing Record 46 of Set 3 | itamarandiba
# City not found. Skipping...
# Processing Record 47 of Set 3 | morganton
# City not found. Skipping...
# Processing Record 48 of Set 3 | bolu
# City not found. Skipping...
# Processing Record 49 of Set 3 | jasa tomic
# City not found. Skipping...
# Processing Record 50 of Set 3 | longyearbyen
# City not found. Skipping...
# Processing Record 1 of Set 4 | krasnoselkup
# City not found. Skipping...
# Processing Record 2 of Set 4 | tasiilaq
# City not found. Skipping...
# Processing Record 3 of Set 4 | ixtapa
# City not found. Skipping...
# Processing Record 4 of Set 4 | turukhansk
# City not found. Skipping...
# Processing Record 5 of Set 4 | souillac
# City not found. Skipping...
# Processing Record 6 of Set 4 | chuy
# City not found. Skipping...
# Processing Record 7 of Set 4 | srednekolymsk
# City not found. Skipping...
# Processing Record 8 of Set 4 | shakawe
# City not found. Skipping...
# Processing Record 9 of Set 4 | kaniama
# City not found. Skipping...
# Processing Record 10 of Set 4 | ubinskoye
# City not found. Skipping...
# Processing Record 11 of Set 4 | margate
# City not found. Skipping...
# Processing Record 12 of Set 4 | kopeysk
# City not found. Skipping...
# Processing Record 13 of Set 4 | caravelas
# City not found. Skipping...
# Processing Record 14 of Set 4 | codrington
# City not found. Skipping...
# Processing Record 15 of Set 4 | sao joao da barra
# City not found. Skipping...
# Processing Record 16 of Set 4 | dryden
# City not found. Skipping...
# Processing Record 17 of Set 4 | pisco
# City not found. Skipping...
# Processing Record 18 of Set 4 | haysville
# City not found. Skipping...
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | tocopilla
# City not found. Skipping...
# Processing Record 21 of Set 4 | katsuura
# City not found. Skipping...
# Processing Record 22 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 4 | inongo
# City not found. Skipping...
# Processing Record 24 of Set 4 | patea
# City not found. Skipping...
# Processing Record 25 of Set 4 | hasaki
# City not found. Skipping...
# Processing Record 26 of Set 4 | mar del plata
# City not found. Skipping...
# Processing Record 27 of Set 4 | banjarmasin
# City not found. Skipping...
# Processing Record 28 of Set 4 | lufilufi
# City not found. Skipping...
# Processing Record 29 of Set 4 | muros
# City not found. Skipping...
# Processing Record 30 of Set 4 | smoky lake
# City not found. Skipping...
# Processing Record 31 of Set 4 | georgetown
# City not found. Skipping...
# Processing Record 32 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 4 | centralina
# City not found. Skipping...
# Processing Record 34 of Set 4 | bequimao
# City not found. Skipping...
# Processing Record 35 of Set 4 | bilma
# City not found. Skipping...
# Processing Record 36 of Set 4 | leningradskiy
# City not found. Skipping...
# Processing Record 37 of Set 4 | meteti
# City not found. Skipping...
# Processing Record 38 of Set 4 | praya
# City not found. Skipping...
# Processing Record 39 of Set 4 | kandiaro
# City not found. Skipping...
# Processing Record 40 of Set 4 | nyagan
# City not found. Skipping...
# Processing Record 41 of Set 4 | tomatlan
# City not found. Skipping...
# Processing Record 42 of Set 4 | nanortalik
# City not found. Skipping...
# Processing Record 43 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 4 | ilebo
# City not found. Skipping...
# Processing Record 45 of Set 4 | fortuna
# City not found. Skipping...
# Processing Record 46 of Set 4 | sarangani
# City not found. Skipping...
# Processing Record 47 of Set 4 | macon
# City not found. Skipping...
# Processing Record 48 of Set 4 | bengkulu
# City not found. Skipping...
# Processing Record 49 of Set 4 | beringovskiy
# City not found. Skipping...
# Processing Record 50 of Set 4 | kirakira
# City not found. Skipping...
# Processing Record 1 of Set 5 | ancud
# City not found. Skipping...
# Processing Record 2 of Set 5 | dire
# City not found. Skipping...
# Processing Record 3 of Set 5 | aklavik
# City not found. Skipping...
# Processing Record 4 of Set 5 | saint george
# City not found. Skipping...
# Processing Record 5 of Set 5 | sur
# City not found. Skipping...
# Processing Record 6 of Set 5 | nchelenge
# City not found. Skipping...
# Processing Record 7 of Set 5 | sovetskiy
# City not found. Skipping...
# Processing Record 8 of Set 5 | port augusta
# City not found. Skipping...
# Processing Record 9 of Set 5 | maldonado
# City not found. Skipping...
# Processing Record 10 of Set 5 | alofi
# City not found. Skipping...
# Processing Record 11 of Set 5 | puli
# City not found. Skipping...
# Processing Record 12 of Set 5 | pavilosta
# City not found. Skipping...
# Processing Record 13 of Set 5 | townsville
# City not found. Skipping...
# Processing Record 14 of Set 5 | ambon
# City not found. Skipping...
# Processing Record 15 of Set 5 | santiago del estero
# City not found. Skipping...
# Processing Record 16 of Set 5 | ahipara
# City not found. Skipping...
# Processing Record 17 of Set 5 | cherskiy
# City not found. Skipping...
# Processing Record 18 of Set 5 | pasighat
# City not found. Skipping...
# Processing Record 19 of Set 5 | esperance
# City not found. Skipping...
# Processing Record 20 of Set 5 | saskylakh
# City not found. Skipping...
# Processing Record 21 of Set 5 | umm lajj
# City not found. Skipping...
# Processing Record 22 of Set 5 | lake city
# City not found. Skipping...
# Processing Record 23 of Set 5 | avera
# City not found. Skipping...
# Processing Record 24 of Set 5 | saurimo
# City not found. Skipping...
# Processing Record 25 of Set 5 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 26 of Set 5 | evensk
# City not found. Skipping...
# Processing Record 27 of Set 5 | ponta do sol
# City not found. Skipping...
# Processing Record 28 of Set 5 | lorengau
# City not found. Skipping...
# Processing Record 29 of Set 5 | kaitangata
# City not found. Skipping...
# Processing Record 30 of Set 5 | japura
# City not found. Skipping...
# Processing Record 31 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 5 | cayenne
# City not found. Skipping...
# Processing Record 33 of Set 5 | meulaboh
# City not found. Skipping...
# Processing Record 34 of Set 5 | te anau
# City not found. Skipping...
# Processing Record 35 of Set 5 | huarmey
# City not found. Skipping...
# Processing Record 36 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 5 | yerbogachen
# City not found. Skipping...
# Processing Record 38 of Set 5 | port keats
# City not found. Skipping...
# Processing Record 39 of Set 5 | velsk
# City not found. Skipping...
# Processing Record 40 of Set 5 | manjeshwar
# City not found. Skipping...
# Processing Record 41 of Set 5 | cocobeach
# City not found. Skipping...
# Processing Record 42 of Set 5 | port-cartier
# City not found. Skipping...
# Processing Record 43 of Set 5 | krasnopillya
# City not found. Skipping...
# Processing Record 44 of Set 5 | urumqi
# City not found. Skipping...
# Processing Record 45 of Set 5 | mangai
# City not found. Skipping...
# Processing Record 46 of Set 5 | talara
# City not found. Skipping...
# Processing Record 47 of Set 5 | mabaruma
# City not found. Skipping...
# Processing Record 48 of Set 5 | arraial do cabo
# City not found. Skipping...
# Processing Record 49 of Set 5 | kodiak
# City not found. Skipping...
# Processing Record 50 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 6 | tura
# City not found. Skipping...
# Processing Record 2 of Set 6 | mongoumba
# City not found. Skipping...
# Processing Record 3 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 6 | anadyr
# City not found. Skipping...
# Processing Record 5 of Set 6 | placido de castro
# City not found. Skipping...
# Processing Record 6 of Set 6 | artigas
# City not found. Skipping...
# Processing Record 7 of Set 6 | aykhal
# City not found. Skipping...
# Processing Record 8 of Set 6 | hovd
# City not found. Skipping...
# Processing Record 9 of Set 6 | severo-kurilsk
# City not found. Skipping...
# Processing Record 10 of Set 6 | jalgaon
# City not found. Skipping...
# Processing Record 11 of Set 6 | vastervik
# City not found. Skipping...
# Processing Record 12 of Set 6 | emerald
# City not found. Skipping...
# Processing Record 13 of Set 6 | aksarka
# City not found. Skipping...
# Processing Record 14 of Set 6 | selje
# City not found. Skipping...
# Processing Record 15 of Set 6 | airai
# City not found. Skipping...
# Processing Record 16 of Set 6 | nagina
# City not found. Skipping...
# Processing Record 17 of Set 6 | thompson
# City not found. Skipping...
# Processing Record 18 of Set 6 | slave lake
# City not found. Skipping...
# Processing Record 19 of Set 6 | lazurne
# City not found. Skipping...
# Processing Record 20 of Set 6 | portland
# City not found. Skipping...
# Processing Record 21 of Set 6 | hofn
# City not found. Skipping...
# Processing Record 22 of Set 6 | kearney
# City not found. Skipping...
# Processing Record 23 of Set 6 | north bend
# City not found. Skipping...
# Processing Record 24 of Set 6 | sangar
# City not found. Skipping...
# Processing Record 25 of Set 6 | imbituba
# City not found. Skipping...
# Processing Record 26 of Set 6 | sitka
# City not found. Skipping...
# Processing Record 27 of Set 6 | aitape
# City not found. Skipping...
# Processing Record 28 of Set 6 | kjollefjord
# City not found. Skipping...
# Processing Record 29 of Set 6 | atambua
# City not found. Skipping...
# Processing Record 30 of Set 6 | illintsi
# City not found. Skipping...
# Processing Record 31 of Set 6 | geraldton
# City not found. Skipping...
# Processing Record 32 of Set 6 | upernavik
# City not found. Skipping...
# Processing Record 33 of Set 6 | lukavac
# City not found. Skipping...
# Processing Record 34 of Set 6 | englehart
# City not found. Skipping...
# Processing Record 35 of Set 6 | nishihara
# City not found. Skipping...
# Processing Record 36 of Set 6 | puerto escondido
# City not found. Skipping...
# Processing Record 37 of Set 6 | eenhana
# City not found. Skipping...
# Processing Record 38 of Set 6 | bandarbeyla
# City not found. Skipping...
# Processing Record 39 of Set 6 | batticaloa
# City not found. Skipping...
# Processing Record 40 of Set 6 | morgan city
# City not found. Skipping...
# Processing Record 41 of Set 6 | kampene
# City not found. Skipping...
# Processing Record 42 of Set 6 | port hardy
# City not found. Skipping...
# Processing Record 43 of Set 6 | bukene
# City not found. Skipping...
# Processing Record 44 of Set 6 | port shepstone

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
